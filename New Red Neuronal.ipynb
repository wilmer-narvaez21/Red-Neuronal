# %%
#librerias a utilizar
import tensorflow as tf#libreria para IA
import numpy as np#trabajar con arreglos numericos
import matplotlib.pyplot as plt

# %%
#declaramos arreglos de numeros con las entradas de celsius y salidas fahrenheit
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %%
#se usa keras para hacer la red mas facil
#especificar las capas de tipos densas en queras,que tienen conexines a cada neurona
#unidades o neuronas de la capa units, input_shape para que registre la capa de la neurona

#capa = tf.keras.layers.Dense(units=1, input_shape=[1])
#usamos modelo secuencial
#modelo = tf.keras.Sequential([capa])
#-------------------------------------------------------------------------------------------------------------
#agregamos mas capas, 3 capas y 3 intermedias
capa1 = tf.keras.layers.Dense(units=3, input_shape=[1])
capa2 = tf.keras.layers.Dense(units=3)
capaSalida = tf.keras.layers.Dense(units=1)
modelo = tf.keras.Sequential([capa1, capa2, capaSalida])

# %%
#compilamos el modelo usando Adam para ajustar los sesgos y pesos de manera eficiente
#se le indica un valor numerico para la tasa de aprendizaje
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'#error cuadratico medio
)

# %%
#Entrenamos el modelo
print("Comenzando entrenamiento...")
#Para entrenar usamos la funcion fit(),pasamos los datos de entrada y resultados esperados
#con la propiedad epochs le decimos cuantas vueltas quieres que lo intente
#la propiedad verbose=false es opcional
historial = modelo.fit(celsius, fahrenheit, epochs=1000)
print("Modelo entrenado!")
# Out:
# Comenzando entrenamiento...
# Epoch 1/1000
# 1/1 [==============================] - 1s 776ms/step - loss: 3231.6931
# Epoch 2/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 1831.9736
# Epoch 3/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 1068.6047
# Epoch 4/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 937.4857
# Epoch 5/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 1251.9851
# Epoch 6/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 1229.4052
# Epoch 7/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 963.4956
# Epoch 8/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 782.0176
# Epoch 9/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 773.3198
# Epoch 10/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 845.6091
# Epoch 11/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 888.5761
# Epoch 12/1000
# ...

# %%
#resultado de la funcion de perdida
#esto nos indica que tan mal estan los resultados de la red en cada vuelta que dio
#
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de perdida")
plt.plot(historial.history["loss"])

# %%
#hagamos una prediccion
print("Hagamos una prediccion!")
resultado = modelo.predict([90.0])
print("El resultado es " + str(resultado) + " fahrenheit!")
# Out:
# Hagamos una prediccion!
# 1/1 [==============================] - 0s 200ms/step
# El resultado es [[193.76794]] fahrenheit!

# %%
#Estruccura interna de la red
#que datos se asignaron despues del entrenamiento y el sesgo
print("Variables internas del modelo")
#print(capa.get_weights())

print(capa1.get_weights())
print(capa2.get_weights())
print(capaSalida.get_weights())
# Out:
# Variables internas del modelo
# [array([[0.2664872 , 0.6360192 , 0.19001728]], dtype=float32), array([ 3.1047752,  3.4366152, -2.7467053], dtype=float32)]
# [array([[-0.42081708, -0.32931852,  0.5122392 ],
#        [-1.3332402 , -0.43206376,  1.12861   ],
#        [-0.2221788 ,  0.8960798 , -0.549568  ]], dtype=float32), array([-2.8242483, -3.3179975,  3.4687557], dtype=float32)]
# [array([[-0.6246984],
#        [-1.2907186],
#        [ 1.2316463]], dtype=float32), array([3.3280642], dtype=float32)]

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 3)                 6
#
#  dense_1 (Dense)             (None, 3)                 12
#
#  dense_2 (Dense)             (None, 1)                 4
#
# ...
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### formula de grador C a F
# ![image.png](attachment:image.png)
